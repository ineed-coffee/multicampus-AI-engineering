# %%
print('This is Jupyter Notebook')
a=3
# Out:
# This is Jupyter Notebook

# %%
import mysql.connector

conn = mysql.connector.connect(user='root', password='1234', host='127.0.0.1', database='employees')
cursor = conn.cursor()
cursor.execute("SELECT DATABASE()")
data = cursor.fetchone()
print("Connection established to: ",data)

conn.close()
# Out:
# Connection established to:  ('employees',)

# %%
import mysql.connector

conn = mysql.connector.connect(
   user='root', password='1234', host='127.0.0.1', database='employees')

cursor = conn.cursor()

sql = '''SELECT * from employees.employees'''

cursor.execute(sql)

result = cursor.fetchone()
print(result)

result = cursor.fetchall()
print(result)

conn.close()
# Out:
# 9, 11, 6), 'Souichi', 'Demri', 'M', datetime.date(1988, 4, 7)), (499784, datetime.date(1959, 4, 12), 'Turgut', 'Levasseur', 'F', datetime.date(1985, 4, 15)), (499785, datetime.date(1956, 12, 22), 'Lakshmi', 'Polajnar', 'F', datetime.date(1997, 12, 9)), (499786, datetime.date(1958, 11, 4), 'Jingling', 'Hasenauer', 'F', datetime.date(1986, 10, 4)), (499787, datetime.date(1957, 4, 4), 'Michaela', 'Wroclawski', 'M', datetime.date(1992, 1, 24)), (499788, datetime.date(1957, 7, 2), 'Matk', 'Goodrum', 'M', datetime.date(1994, 4, 25)), (499789, datetime.date(1961, 3, 29), 'Chuanti', 'Jonsson', 'M', datetime.date(1987, 7, 20)), (499790, datetime.date(1954, 5, 25), 'Mechthild', 'Poupard', 'F', datetime.date(1992, 7, 9)), (499791, datetime.date(1960, 10, 30), 'Kotesh', 'Plumb', 'M', datetime.date(1986, 6, 9)), (499792, datetime.date(1962, 2, 4), 'Ekawit', 'Sinicrope', 'M', datetime.date(1993, 2, 11)), (499793, datetime.date(1956, 5, 21), 'Feipei', 'Setlzner', 'M', datetime.date(1988, 12, 7)), (499794, datetime.date(1963, 11, 5), 'Saniya', 'Hettesheimer', 'M', datetime.date(1992, 3, 1)), (499795, datetime.date(1961, 7, 5), 'Idoia', 'Riefers', 'M', datetime.date(1986, 1, 16)), (499796, datetime.date(1963, 6, 11), 'Shigeu', 'Crouzet', 'M', datetime.date(1993, 1, 14)), (499797, datetime.date(1952, 3, 11), 'Wayne', 'Hutter', 'M', datetime.date(1988, 8, 28)), (499798, datetime.date(1953, 8, 20), 'Gopalakrishnan', 'Maierhofer', 'F', datetime.date(1990, 1, 3)), (499799, datetime.date(1962, 8, 23), 'Howell', 'Petereit', 'M', datetime.date(1989, 8, 10)), (499800, datetime.date(1953, 6, 1), 'Danny', 'Barvinok', 'F', datetime.date(1989, 5, 12)), (499801, datetime.date(1959, 1, 19), 'Sverrir', 'Pelc', 'F', datetime.date(1987, 5, 25)), (499802, datetime.date(1962, 3, 7), 'Eckart', 'Vrecion', 'M', datetime.date(1985, 8, 9)), (499803, datetime.date(1963, 3, 25), 'Van', 'Zykh', 'M', datetime.date(1991, 6, 3)), (499804, datetime.date(1960, 3, 23), 'Leen', 'Emmart', 'F', datetime.date(1989, 1, 19)), (499805, datetime.date(1956, 8, 22), 'Mitchel', 'Rosti', 'M', datetime.date(1992, 10, 1)), (499806, datetime.date(1958, 10, 11), 'Ingmar', 'Barbanera', 'F', datetime.date(1995, 4, 14)), (499807, datetime.date(1956, 11, 23), 'Foong', 'Godskesen', 'M', datetime.date(1989, 11, 1)), (499808, datetime.date(1955, 4, 5), 'Paris', 'Deyuan', 'F', datetime.date(1987, 12, 21)), (499809, datetime.date(1958, 8, 2), 'Zdislav', 'Nittel', 'M', datetime.date(1991, 3, 31)), (499810, datetime.date(1959, 7, 7), 'Soenke', 'Kalorkoti', 'F', datetime.date(1986, 2, 2)), (499811, datetime.date(1964, 8, 31), 'Danae', 'Sevcikova', 'M', datetime.date(1992, 11, 20)), (499812, datetime.date(1962, 3, 27), 'Ulf', 'Mapelli', 'F', datetime.date(1994, 10, 10)), (499813, datetime.date(1958, 11, 19), 'Aiman', 'Maccarone', 'M', datetime.date(1987, 5, 20)), (499814, datetime.date(1960, 12, 28), 'Georgi', 'Wielonsky', 'M', datetime.date(1989, 1, 31)), (499815, datetime.date(1962, 8, 16), 'Hyuckchul', 'Baar', 'F', datetime.date(1987, 4, 25)), (499816, datetime.date(1952, 9, 1), 'Debatosh', 'Murtagh', 'M', datetime.date(1987, 9, 15)), (499817, datetime.date(1953, 8, 3), 'Lihong', 'Pusterhofer', 'M', datetime.date(1986, 11, 27)), (499818, datetime.date(1963, 4, 10), 'Kokou', 'Angelov', 'M', datetime.date(1986, 9, 9)), (499819, datetime.date(1955, 10, 19), 'Behnaam', 'Sooriamurthi', 'M', datetime.date(1989, 8, 18)), (499820, datetime.date(1956, 1, 23), 'Akeel', 'Baez', 'M', datetime.date(1987, 10, 27)), (499821, datetime.date(1957, 3, 15), 'Kazuhisa', 'Raney', 'F', datetime.date(1992, 5, 22)), (499822, datetime.date(1956, 10, 8), 'Serif', 'Thebaut', 'M', datetime.date(1989, 5, 11)), (499823, datetime.date(1956, 12, 27), 'Changho', 'Noriega', 'F', datetime.date(1994, 11, 19)), (499824, datetime.date(1958, 12, 8), 'Licheng', 'Stanfel', 'F', datetime.date(1990, 2, 19)), (499825, datetime.date(1953, 4, 23), 'Kwun', 'Remmele', 'F', datetime.date(1996, 1, 13)), (499826, datetime.date(1960, 4, 9), 'Serge', 'Tis ...
