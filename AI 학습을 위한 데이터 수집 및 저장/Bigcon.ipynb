# %%
f = open('C:/Users/i/Desktop/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_201902.CSV','r',encoding='utf-8')
txt = f.read()
txt=txt.replace('|',',')
f.close()
txt
f = open('C:/Users/i/Desktop/test.csv','w',encoding='utf-8')
f.write(txt)
f.close()

# %%
import pandas as pd

txt_df =pd.read_csv('C:/Users/i/Desktop/test.csv',encoding='utf-8')

# %%
txt_df
# Out:
#       STD_YM   STD_YMD    HDONG_CD HDONG_NM  MAN_FLOW_POP_CNT_0004  \
# 0     201902  20190201  1114052000      소공동                  16.64
# 1     201902  20190202  1114052000      소공동                   3.14
# 2     201902  20190203  1114052000      소공동                   1.38
# 3     201902  20190204  1114052000      소공동                   0.08
# 4     201902  20190205  1114052000      소공동                   0.00
# ...      ...       ...         ...      ...                    ...
# 1927  201902  20190224  2726069000     고산3동                   0.05
# 1928  201902  20190225  2726069000     고산3동                   0.05
# 1929  201902  20190226  2726069000     고산3동                   0.03
# 1930  201902  20190227  2726069000     고산3동                   0.08
# 1931  201902  20190228  2726069000     고산3동                   0.19
#
#       MAN_FLOW_POP_CNT_0509  MAN_FLOW_POP_CNT_1014  MAN_FLOW_POP_CNT_1519  \
# 0                    116.18                 419.70                1553.57
# ...

# %%
f = open('C:/Users/i/Desktop/2020빅콘테스트 문제데이터(혁신아이디어분야)/03_SNS데이터(와이즈넛)/2020 bigcontest data_wisenut.csv','r',encoding='utf-8')
txt = f.read()
f.close()
txt
# Out:
# 'SEQ\x07GU_CD\x07GU_NM(삭제)\x07DONG_CD\x07DONG_NM(삭제)\x07NEWS_CNT_201902\x07NEWS_CNT_201903\x07NEWS_CNT_201904\x07NEWS_CNT_201905\x07NEWS_CNT_202002\x07NEWS_CNT_202003\x07NEWS_CNT_202004\x07NEWS_CNT_202005\x07BLOG_CNT_201902\x07BLOG_CNT_201903\x07BLOG_CNT_201904\x07BLOG_CNT_201905\x07BLOG_CNT_202002\x07BLOG_CNT_202003\x07BLOG_CNT_202004\x07BLOG_CNT_202005\x07CAFE_CNT_201902\x07CAFE_CNT_201903\x07CAFE_CNT_201904\x07CAFE_CNT_201905\x07CAFE_CNT_202002\x07CAFE_CNT_202003\x07CAFE_CNT_202004\x07CAFE_CNT_202005\x07UP_TOPIC_201902\x07UP_TOPIC_201903\x07UP_TOPIC_201904\x07UP_TOPIC_201905\x07UP_TOPIC_202002\x07UP_TOPIC_202003\x07UP_TOPIC_202004\x07UP_TOPIC_202005\x07UP1_POSITIVE_201902\x07UP1_POSITIVE_201903\x07UP1_POSITIVE_201904\x07UP1_POSITIVE_201905\x07UP1_POSITIVE_202002\x07UP1_POSITIVE_202003\x07UP1_POSITIVE_202004\x07UP1_POSITIVE_202005\x07UP2_POSITIVE_201902\x07UP2_POSITIVE_201903\x07UP2_POSITIVE_201904\x07UP2_POSITIVE_201905\x07UP2_POSITIVE_202002\x07UP2_POSITIVE_202003\x07UP2_POSITIVE
# ...
