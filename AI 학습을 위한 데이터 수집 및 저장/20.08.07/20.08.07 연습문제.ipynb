# %% [markdown]
# # __1. 네이버-> '파이썬'검색-> 지식인-> 질문 추출__

# %%
from bs4 import BeautifulSoup as BS
from urllib.request import urlopen

base_url = 'https://search.naver.com/search.naver?where=kin&kin_display=10&qt=&title=0&&answer=0&grade=0&choice=0&sec=0&nso=so%3Ar%2Ca%3Aall%2Cp%3Aall&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&c_id=&c_name=&sm=tab_pge&kin_start='

for page in range(10):
    print(f'{page+1}페이지 질문','-'*20)
    url=base_url+str(i)+'1'
    response = urlopen(url)
    soap=BS(response,'lxml')
    q_title = soap.select('dt.question > a')
    for j in range(len(q_title)):
        print(f'{j+1:>2}. {q_title[j].text}')
    print()
# Out:
# 1페이지 질문 --------------------
#  1.  코딩 파이썬 질문드립니다
#  2.  파이썬 코딩 질문
#  3.  아두이노 입문 파이썬 코딩
#  4.  파이썬강의 보면서 코딩독학하기
#  5.  파이썬 오류
#  6.  마인크래프트 파이썬
#  7.  파이썬 설치에 대해...
#  8.  파이썬 공부 팁
#  9.  파이썬 공부
# 10.  파이썬프로그래밍을 배우면 일본취업에 유리할까요?
#
# 2페이지 질문 --------------------
#  1.  코딩 파이썬 질문드립니다
#  2.  파이썬 코딩 질문
#  3.  아두이노 입문 파이썬 코딩
#  4.  파이썬강의 보면서 코딩독학하기
#  5.  파이썬 오류
#  6.  마인크래프트 파이썬
#  7.  파이썬 설치에 대해...
#  8.  파이썬 공부 팁
#  9.  파이썬 공부
# 10.  파이썬프로그래밍을 배우면 일본취업에 유리할까요?
#
# 3페이지 질문 --------------------
#  1.  코딩 파이썬 질문드립니다
#  2.  파이썬 코딩 질문
#  3.  아두이노 입문 파이썬 코딩
#  4.  파이썬강의 보면서 코딩독학하기
#  5.  파이썬 오류
#  6.  마인크래프트 파이썬
#  7.  파이썬 설치에 대해...
#  8.  파이썬 공부 팁
#  9.  파이썬 공부
# 10.  파이썬프로그래밍을 배우면 일본취업에 유리할까요?
#
# 4페이지 질문 --------------------
#  1.  코딩 파이썬 질문드립니다
#  2.  파이썬 코딩 질문
#  3.  아두이노 입문 파이썬 코딩
#  4.  파이썬강의 보면서 코딩독학하기
#  5.  파이썬 오류
#  6.  마인크래프트 파이썬
#  7.  파이썬 설치에 대해...
#  8.  파이썬 공부 팁
#  9.  파이썬 공부
# 10.  파이썬프로그래밍을 배우면 일본취업에 유리할까요?
#
# 5페이지 질문 --------------------
#  1.  코딩 파이썬 질문드립니다
#  2.  파이썬 코딩 질문
#  3.  아두이노 입문 파이썬 코딩
#  4.  파이썬강의 보면서 코딩독학하기
#  5.  파이썬 오류
#  6.  마인크래프트 파이썬
#  7.  파이썬 설치에 대해...
#  8.  파이썬 공부 팁
#  9.  파이썬 공부
# 10.  파이썬프로그래밍을 배우면 일본취업에 유리할까요?
#
# 6페이지 질문 --------------------
#  1.  코딩 파이썬 질문드립니다
#  2.  파이썬 코딩 질문
#  3.  아두이노 입문 파이썬 코딩
#  4.  파이썬강의 보면서 코딩독학하기
#  5.  파이썬 오류
#  6.  마인크래프트 파이썬
#  7.  파이썬 설치에 대해...
#  8.  파이썬 공부 팁
#  9.  파이썬 공부
# 10.  파이썬프로그래밍을 배우면 일본취업에 유리할까요?
#
# 7페이지 질문 --------------------
#  1.  코딩 파이썬 질문드립니다
#  2.  파이썬 코딩 질문
#  3.  아두이노 입문 파이썬 코딩
#  4.  파이썬강의 보면서 코딩독학하기
#  5.  파이썬 오류
#  6.  마인크래프트 파이썬
#  7.  파이썬 설치에 대해...
#  8.  파이썬 공부 팁
#  9.  파이썬 공부
# 10.  파이썬프로그래밍을 배우면 일본취업에 유리할까요?
#
# 8페이지 질문 --------------------
#  1.  코딩 파이썬 질문드립니다
#  2.  파이썬 코딩 질문
#  3.  아두이노 입문 파이썬 코딩
#  4.  파이썬강의 보면서 코딩독학하기
#  5.  파이썬 오류
#  6.  마인크래프트 파이썬
#  7.  파이썬 설치에 대해...
#  8.  파이썬 공부 팁
#  9.  파이썬 공부
# 10.  파이썬프로그래밍을 배우면 일본취업에 유리할까요?
#
# 9페이지 질문 --------------------
#  1.  코딩 파이썬 질문드립니다
#  2.  파이썬 코딩 질문
#  3.  아두이노 입문 파이썬 코딩
#  4.  파이썬강의 보면서 코딩독학하기
#  5.  파이썬 오류
#  6.  마인크래프트 파이썬
#  7.  파이썬 설치에 대해...
#  8.  파이썬 공부 팁
#  9.  파이썬 공부
# 10.  파이썬프로그래밍을 배우면 일본취업에 유리할까요?
#
# 10페이지 질문 --------------------
#  1.  코딩 파이썬 질문드립니다
#  2.  파이썬 코딩 질문
#  3.  아두이노 입문 파이썬 코딩
#  4.  파이썬강의 보면서 코딩독학하기
#  5.  파이썬 오류
#  6.  마인크래프트 파이썬
#  7.  파이썬 설치에 대해...
#  8.  파이썬 공부 팁
#  9.  파이썬 공부
# 10.  파이썬프로그래밍을 배우면 일본취업에 유리할까요?

# %% [markdown]
# # 2. 다나와-> 노트북 페이지
# ### * 가격
# ### * 화면
# ### * CPU
# ### * 코어
# ### * SSD
# ### * RAM
# ### * 제조사

# %%
from bs4 import BeautifulSoup as BS
from urllib.request import urlopen
from selenium import webdriver
import re

Results=[]
driver = webdriver.Chrome('c:/mychrome/chromedriver.exe')
url = 'http://prod.danawa.com/list/?cate=112758&15main_11_02'
driver.get(url)
html = driver.page_source
soap = BS(html,'html.parser')

Laps = soap.select('.prod_main_info')

for lap in Laps:
    spec = lap.text
    prod = re.search('LG전자|삼성전자',spec)
    price = re.search('[\d,]+0원',spec)
    print(prod,price)
    print('='*20)
# Out:
# <re.Match object; span=(25, 29), match='삼성전자'> <re.Match object; span=(603, 611), match='673,000원'>
# ====================
# None <re.Match object; span=(665, 675), match='1,190,000원'>
# ====================
# <re.Match object; span=(34, 38), match='LG전자'> <re.Match object; span=(695, 705), match='1,325,000원'>
# ====================
# None <re.Match object; span=(692, 702), match='1,850,000원'>
# ====================
# None <re.Match object; span=(719, 727), match='924,000원'>
# ====================
# <re.Match object; span=(32, 36), match='삼성전자'> <re.Match object; span=(593, 601), match='673,000원'>
# ====================
# <re.Match object; span=(41, 45), match='LG전자'> <re.Match object; span=(703, 713), match='1,339,000원'>
# ====================
# None <re.Match object; span=(719, 727), match='765,000원'>
# ====================
# None <re.Match object; span=(631, 639), match='440,000원'>
# ====================
# <re.Match object; span=(34, 38), match='삼성전자'> <re.Match object; span=(713, 723), match='1,366,000원'>
# ====================
# None <re.Match object; span=(653, 661), match='895,000원'>
# ====================
# <re.Match object; span=(32, 36), match='LG전자'> <re.Match object; span=(688, 698), match='1,450,000원'>
# ====================
# <re.Match object; span=(41, 45), match='LG전자'> <re.Match object; span=(736, 746), match='1,325,000원'>
# ====================
# None <re.Match object; span=(554, 564), match='1,669,000원'>
# ====================
# <re.Match object; span=(32, 36), match='LG전자'> <re.Match object; span=(677, 687), match='1,355,000원'>
# ====================
# None <re.Match object; span=(694, 704), match='1,373,000원'>
# ====================
# None <re.Match object; span=(706, 716), match='2,929,000원'>
# ====================
# None <re.Match object; span=(656, 666), match='1,190,000원'>
# ====================
# <re.Match object; span=(42, 46), match='삼성전자'> <re.Match object; span=(573, 583), match='2,098,000원'>
# ====================
# None <re.Match object; span=(733, 743), match='1,510,000원'>
# ====================
# None <re.Match object; span=(688, 696), match='869,000원'>
# ====================
# None <re.Match object; span=(694, 704), match='1,190,000원'>
# ====================
# None <re.Match object; span=(678, 686), match='660,000원'>
# ====================
# None <re.Match object; span=(686, 696), match='1,062,000원'>
# ====================
# None <re.Match object; span=(683, 691), match='810,000원'>
# ====================
# None <re.Match object; span=(689, 699), match='1,410,000원'>
# ====================
# <re.Match object; span=(42, 46), match='삼성전자'> <re.Match object; span=(708, 718), match='1,366,000원'>
# ====================
# None <re.Match object; span=(772, 780), match='744,000원'>
# ====================
# None <re.Match object; span=(670, 678), match='880,000원'>
# ====================
# None <re.Match object; span=(534, 544), match='1,488,960원'>
# ====================
# None <re.Match object; span=(644, 652), match='895,000원'>
# ====================
# None <re.Match object; span=(749, 759), match='1,300,000원'>
# ====================
# None <re.Match object; span=(662, 672), match='1,210,000원'>
# ====================
# <re.Match object; span=(33, 37), match='삼성전자'> <re.Match object; span=(778, 788), match='1,407,000원'>
# ====================
# None <re.Match object; span=(727, 737), match='1,009,000원'>
# ====================
# None <re.Match object; span=(673, 683), match='1,398,000원'>
# ====================

# %%
lapps[0].text
# Out:
# '\n\n\n\n\n이미지보기\n\n\n\n\n\t\t\t\t\t\t\t\t\t\tLG전자 2020 그램17 17ZD995-VX50K (SSD 256GB)\t\t\t\t\t\t\t\t\t\n\n\n\n\n상세 스펙\n\n\n\n43.1cm(17인치) / 인텔 / 코어i5-10세대 / 코멧레이크 / i5-10210U 1.6GHz(4.2GHz) / 쿼드코어 / 2560x1600(WQXGA) / 광시야각(IPS) / 슬림형 베젤 / DDR4 / 8GB / M.2(NVMe) / SSD: 256GB / UHD Graphics / 802.11ax(Wi-Fi 6) / 블루투스 / HDMI / 웹캠(HD) / 썬더볼트: 1개 / USB 3.1 Type-C / USB 3.1 / MicroSD카드 / 숫자 키패드 / 키보드 라이트 / MIL-STD / 지문 인식 / USB-PD / 배터리: 72Wh / 운영체제: 미포함(프리도스) / 두께: 17.4mm / 무게: 1.34kg / 일반유통상품 / 용도: 사무/인강용, 휴대용 / 색상: 화이트\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\n관련기사슬림 노트북4종 비교 갤럭시북플렉스?이온? 20년형 그램17 아니면 삼성노트북플러스? 노트북 살땐 모던PC\n\n\n\n등록월\n2020.01\n\n상품의견\xa0177건\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t관심상품\n\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t135몰\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n상품비교\n\n\n\n1,450,000원\n\n가격정보 더보기\n\n\n\n\n\n\n\n'
